# %%
# %pwd
# Out:
# '/content'

# %%
# %cd /content/drive/MyDrive/KGSF---movie-recommender-system/
# Out:
# /content/drive/MyDrive/KGSF---movie-recommender-system

# %%
# !pip install torch_geometric torch_sparse torch_scatter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 407 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 51 kB 249 kB/s
# ...
#   Created wheel for torch-geometric: filename=torch_geometric-2.0.4-py3-none-any.whl size=616603 sha256=5797b11ba4f4fbceca8c48dcf39e9c81102efe688eb7f8af350f728a72104e53
#   Stored in directory: /root/.cache/pip/wheels/18/a6/a4/ca18c3051fcead866fe7b85700ee2240d883562a1bc70ce421
# ...
#   Created wheel for torch-sparse: filename=torch_sparse-0.6.14-cp37-cp37m-linux_x86_64.whl size=1647901 sha256=6f1edb785847bd98d1b4aa4a1da92235c70198ac546aea1cac4d5d142c9c7e0f
#   Stored in directory: /root/.cache/pip/wheels/3c/aa/62/db0259eae2abce84f1ee2cf1c531bba683aab4bf79054172f8
# ...
#   Created wheel for torch-scatter: filename=torch_scatter-2.0.9-cp37-cp37m-linux_x86_64.whl size=3861165 sha256=35a6da7d50a4652443eb53c60178e964599094aedfb0eb806b7a77be8bbd3e8d
# ...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# !python run.py --epoch 10
# Out:
# {'max_c_length': 256, 'max_r_length': 256, 'batch_size': 32, 'max_count': 5, 'use_cpu': True, 'load_dict': None, 'learningrate': 0.001, 'optimizer': 'adam', 'momentum': 0, 'is_finetune': False, 'embedding_type': 'random', 'epoch': 10, 'gpu': '0,1', 'gradient_clip': 0.1, 'embedding_size': 300, 'n_heads': 2, 'n_layers': 2, 'ffn_size': 300, 'dropout': 0.1, 'attention_dropout': 0.0, 'relu_dropout': 0.1, 'learn_positional_embeddings': False, 'embeddings_scale': True, 'n_entity': 64368, 'n_relation': 214, 'n_concept': 29308, 'n_con_relation': 48, 'dim': 128, 'n_hop': 2, 'kge_weight': 1, 'l2_weight': 2.5e-06, 'n_memory': 32, 'item_update_mode': '0,1', 'using_all_hops': True, 'num_bases': 8}
# 100it [00:00, 182.17it/s]
# 365028 46
# ...

# %%
# !python run.py --is_finetune True --epoch 10
# Out:
# {'max_c_length': 256, 'max_r_length': 256, 'batch_size': 32, 'max_count': 5, 'use_cpu': True, 'load_dict': None, 'learningrate': 0.001, 'optimizer': 'adam', 'momentum': 0, 'is_finetune': True, 'embedding_type': 'random', 'epoch': 10, 'gpu': '0,1', 'gradient_clip': 0.1, 'embedding_size': 300, 'n_heads': 2, 'n_layers': 2, 'ffn_size': 300, 'dropout': 0.1, 'attention_dropout': 0.0, 'relu_dropout': 0.1, 'learn_positional_embeddings': False, 'embeddings_scale': True, 'n_entity': 64368, 'n_relation': 214, 'n_concept': 29308, 'n_con_relation': 48, 'dim': 128, 'n_hop': 2, 'kge_weight': 1, 'l2_weight': 2.5e-06, 'n_memory': 32, 'item_update_mode': '0,1', 'using_all_hops': True, 'num_bases': 8}
# 100it [00:00, 435.68it/s]
# 365028 46
# ...
